# %% [markdown]
# # Import necessary depencencies

# %%
import pandas as pd
import numpy as np
import text_normalizer as tn
import model_evaluation_utils as meu  ## Not provided to you
# The Intern can code the methods to print the Metric like accuracy,
# and confusion matrix. The o/ps in the below cells would give an idea.

np.set_printoptions(precision=2, linewidth=80)

# %% [markdown]
# # Load and normalize data

# %%
dataset = pd.read_csv(r'IMDB Dataset.csv')

reviews = np.array(dataset['review'])
sentiments = np.array(dataset['sentiment'])

# extract data for model evaluation
test_reviews = reviews[35000:]
test_sentiments = sentiments[35000:]
sample_review_ids = [7626, 3533, 13010]

print("done")
# Out:
# done

# %%
# normalize dataset
norm_test_reviews = tn.normalize_corpus(test_reviews)
print("done")
# Out:
# done

# %% [markdown]
# # Sentiment Analysis with AFINN

# %%
from afinn import Afinn

afn = Afinn(emoticons=True)

# %% [markdown]
# ## Predict sentiment for sample reviews

# %%
for review, sentiment in zip(test_reviews[sample_review_ids], test_sentiments[sample_review_ids]):
    print('REVIEW:', review)
    print('Actual Sentiment:', sentiment)
    print('Predicted Sentiment polarity:', afn.score(review))
    print('-'*60)
# Out:
# REVIEW: no comment - stupid movie, acting average or worse... screenplay - no sense at all... SKIP IT!
# Actual Sentiment: negative
# Predicted Sentiment polarity: -7.0
# ------------------------------------------------------------
# REVIEW: I don't care if some people voted this movie to be bad. If you want the Truth this is a Very Good Movie! It has every thing a movie should have. You really should Get this one.
# Actual Sentiment: positive
# Predicted Sentiment polarity: 3.0
# ------------------------------------------------------------
# REVIEW: Worst horror film ever but funniest film ever rolled in one you have got to see this film it is so cheap it is unbeliaveble but you have to see it really!!!! P.s watch the carrot
# Actual Sentiment: positive
# Predicted Sentiment polarity: -3.0
# ------------------------------------------------------------

# %% [markdown]
# ## Predict sentiment for test dataset

# %%
sentiment_polarity = [afn.score(review) for review in test_reviews]
predicted_sentiments = ['positive' if score >= 1.0 else 'negative' for score in sentiment_polarity]

# %% [markdown]
# ## Evaluate model performance

# %%
# Performance Metrics for Afinn
# Please Note : the module meu is not been provided. 
meu.display_model_performance_metrics(true_labels=test_sentiments, 
                                      predicted_labels=predicted_sentiments, 
                                  classes=['positive', 'negative'])

# THE BELOW O/P SHOULD GIVE YOU A FAIR IDEA ON WHAT :
# methods like 
# display_model_performance_metrics() are doing and printing as o/p.

# As an Intern you are not suppose to produce the exact o/p 
# You may only code the minimum required metrics which helps you to 
# compare the different ML models.
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.7118
# Precision: 0.7289
# Recall: 0.7118
# F1 Score: 0.7062
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#     positive       0.67      0.85      0.75      7510
#     negative       0.79      0.57      0.67      7490
#
#     accuracy                           0.71     15000
#    macro avg       0.73      0.71      0.71     15000
# weighted avg       0.73      0.71      0.71     15000
#
#
# Prediction Confusion Matrix:
# ------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e6f81a76a28b> in <module>
#       1 # Performance Metrics for Afinn
#       2 # Please Note : the module meu is not been provided.
# ----> 3 meu.display_model_performance_metrics(true_labels=test_sentiments,
#       4                                       predicted_labels=predicted_sentiments,
#       5                                   classes=['positive', 'negative'])
#
# ~/Downloads/Sentiment Analysis Project Specs n Resources/model_evaluation_utils.py in display_model_performance_metrics(true_labels, predicted_labels, classes)
#      83     print('\nPrediction Confusion Matrix:')
#      84     print('-'*30)
# ---> 85     display_confusion_matrix(true_labels=true_labels, predicted_labels=predicted_labels,
#      86                              classes=classes)
#      87
#
# ~/Downloads/Sentiment Analysis Project Specs n Resources/model_evaluation_utils.py in display_confusion_matrix(true_labels, predicted_labels, classes)
#      58                                   labels=classes)
#      59     cm_frame = pd.DataFrame(data=cm,
# ---> 60                             columns=pd.MultiIndex(levels=[['Predicted:'], classes],
#      61                                                   labels=level_labels),
#      62                             index=pd.MultiIndex(levels=[['Actual:'], classes],
#
# TypeError: __new__() got an unexpected keyword argument 'labels'

# %% [markdown]
# # Sentiment Analysis with SentiWordNet

# %%
from nltk.corpus import sentiwordnet as swn

awesome = list(swn.senti_synsets('awesome', 'a'))[0]
print('Positive Polarity Score:', awesome.pos_score())
print('Negative Polarity Score:', awesome.neg_score())
print('Objective Score:', awesome.obj_score())
# Out:
# Positive Polarity Score: 0.875
# Negative Polarity Score: 0.125
# Objective Score: 0.0

# %% [markdown]
# ## Build model

# %%
def analyze_sentiment_sentiwordnet_lexicon(review,
                                           verbose=False):

    # tokenize and POS tag text tokens
    tagged_text = [(token.text, token.tag_) for token in tn.nlp(review)]
    pos_score = neg_score = token_count = obj_score = 0
    # get wordnet synsets based on POS tags
    # get sentiment scores if synsets are found
    for word, tag in tagged_text:
        ss_set = None
        if 'NN' in tag and list(swn.senti_synsets(word, 'n')):
            ss_set = list(swn.senti_synsets(word, 'n'))[0]
        elif 'VB' in tag and list(swn.senti_synsets(word, 'v')):
            ss_set = list(swn.senti_synsets(word, 'v'))[0]
        elif 'JJ' in tag and list(swn.senti_synsets(word, 'a')):
            ss_set = list(swn.senti_synsets(word, 'a'))[0]
        elif 'RB' in tag and list(swn.senti_synsets(word, 'r')):
            ss_set = list(swn.senti_synsets(word, 'r'))[0]
        # if senti-synset is found        
        if ss_set:
            # add scores for all found synsets
            pos_score += ss_set.pos_score()
            neg_score += ss_set.neg_score()
            obj_score += ss_set.obj_score()
            token_count += 1
    
    # aggregate final scores
    final_score = pos_score - neg_score
    norm_final_score = round(float(final_score) / token_count, 2)
    final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
    if verbose:
        norm_obj_score = round(float(obj_score) / token_count, 2)
        norm_pos_score = round(float(pos_score) / token_count, 2)
        norm_neg_score = round(float(neg_score) / token_count, 2)
        # to display results in a nice table
        sentiment_frame = pd.DataFrame([[final_sentiment, norm_obj_score, norm_pos_score, 
                                         norm_neg_score, norm_final_score]],
                                       columns=pd.MultiIndex(levels=[['SENTIMENT STATS:'], 
                                                             ['Predicted Sentiment', 'Objectivity',
                                                              'Positive', 'Negative', 'Overall']], 
                                                             labels=[[0,0,0,0,0],[0,1,2,3,4]]))
        print(sentiment_frame)
        
    return final_sentiment

# %% [markdown]
# ## Predict sentiment for sample reviews

# %%
for review, sentiment in zip(test_reviews[sample_review_ids], test_sentiments[sample_review_ids]):
    print('REVIEW:', review)
    print('Actual Sentiment:', sentiment)
    pred = analyze_sentiment_sentiwordnet_lexicon(review, verbose=True)    
    print('-'*60)
# Out:
# REVIEW: no comment - stupid movie, acting average or worse... screenplay - no sense at all... SKIP IT!
# Actual Sentiment: negative
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-78b63ef19046> in <module>
#       2     print('REVIEW:', review)
#       3     print('Actual Sentiment:', sentiment)
# ----> 4     pred = analyze_sentiment_sentiwordnet_lexicon(review, verbose=True)
#       5     print('-'*60)
#
# <ipython-input-10-3d8bc2fa2502> in analyze_sentiment_sentiwordnet_lexicon(review, verbose)
#      36         sentiment_frame = pd.DataFrame([[final_sentiment, norm_obj_score, norm_pos_score,
#      37                                          norm_neg_score, norm_final_score]],
# ---> 38                                        columns=pd.MultiIndex(levels=[['SENTIMENT STATS:'],
#      39                                                              ['Predicted Sentiment', 'Objectivity',
#      40                                                               'Positive', 'Negative', 'Overall']],
#
# TypeError: __new__() got an unexpected keyword argument 'labels'

# %% [markdown]
# ## Predict sentiment for test dataset

# %%
predicted_sentiments = [analyze_sentiment_sentiwordnet_lexicon(review, verbose=False) for review in norm_test_reviews]

# %% [markdown]
# ## Evaluate model performance

# %%
# Performance Metrics on SentiWordNet
# Please Note : the module meu is not been provided.
meu.display_model_performance_metrics(true_labels=test_sentiments, predicted_labels=predicted_sentiments, 
                                  classes=['positive', 'negative'])


# THE BELOW O/P SHOULD GIVE YOU A FAIR IDEA ON WHAT :
# methods like 
# display_model_performance_metrics() are doing and printing as o/p.

# As an Intern you are not suppose to produce the exact o/p 
# You may only code the minimum required metrics which helps you to 
# compare the different ML models.
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.6902
# Precision: 0.6922
# Recall: 0.6902
# F1 Score: 0.6894
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#     positive       0.67      0.74      0.71      7510
#     negative       0.71      0.64      0.67      7490
#
#     accuracy                           0.69     15000
#    macro avg       0.69      0.69      0.69     15000
# weighted avg       0.69      0.69      0.69     15000
#
#
# Prediction Confusion Matrix:
# ------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9ce8e95b4f45> in <module>
#       1 # Performance Metrics on SentiWordNet
#       2 # Please Note : the module meu is not been provided.
# ----> 3 meu.display_model_performance_metrics(true_labels=test_sentiments, predicted_labels=predicted_sentiments,
#       4                                   classes=['positive', 'negative'])
#       5
#
# ~/Downloads/Sentiment Analysis Project Specs n Resources/model_evaluation_utils.py in display_model_performance_metrics(true_labels, predicted_labels, classes)
#      83     print('\nPrediction Confusion Matrix:')
#      84     print('-'*30)
# ---> 85     display_confusion_matrix(true_labels=true_labels, predicted_labels=predicted_labels,
#      86                              classes=classes)
#      87
#
# ~/Downloads/Sentiment Analysis Project Specs n Resources/model_evaluation_utils.py in display_confusion_matrix(true_labels, predicted_labels, classes)
#      58                                   labels=classes)
#      59     cm_frame = pd.DataFrame(data=cm,
# ---> 60                             columns=pd.MultiIndex(levels=[['Predicted:'], classes],
#      61                                                   labels=level_labels),
#      62                             index=pd.MultiIndex(levels=[['Actual:'], classes],
#
# TypeError: __new__() got an unexpected keyword argument 'labels'

# %% [markdown]
# # Sentiment Analysis with VADER

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# ## Build model

# %%
def analyze_sentiment_vader_lexicon(review, 
                                    threshold=0.1,
                                    verbose=False):
    # pre-process text
    review = tn.strip_html_tags(review)
    review = tn.remove_accented_chars(review)
    review = tn.expand_contractions(review)
    
    # analyze the sentiment for review
    analyzer = SentimentIntensityAnalyzer()
    scores = analyzer.polarity_scores(review)
    # get aggregate scores and final sentiment
    agg_score = scores['compound']
    final_sentiment = 'positive' if agg_score >= threshold\
                                   else 'negative'
    if verbose:
        # display detailed sentiment statistics
        positive = str(round(scores['pos'], 2)*100)+'%'
        final = round(agg_score, 2)
        negative = str(round(scores['neg'], 2)*100)+'%'
        neutral = str(round(scores['neu'], 2)*100)+'%'
        sentiment_frame = pd.DataFrame([[final_sentiment, final, positive,
                                        negative, neutral]],
                                        columns=pd.MultiIndex(levels=[['SENTIMENT STATS:'], 
                                                                      ['Predicted Sentiment', 'Polarity Score',
                                                                       'Positive', 'Negative', 'Neutral']], 
                                                              labels=[[0,0,0,0,0],[0,1,2,3,4]]))
        print(sentiment_frame)
    
    return final_sentiment

# %% [markdown]
# ## Predict sentiment for sample reviews

# %%
for review, sentiment in zip(test_reviews[sample_review_ids], test_sentiments[sample_review_ids]):
    print('REVIEW:', review)
    print('Actual Sentiment:', sentiment)
    pred = analyze_sentiment_vader_lexicon(review, threshold=0.4, verbose=True)    
    print('-'*60)
# Out:
# REVIEW: no comment - stupid movie, acting average or worse... screenplay - no sense at all... SKIP IT!
# Actual Sentiment: negative
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-319c4bac66a2> in <module>
#       2     print('REVIEW:', review)
#       3     print('Actual Sentiment:', sentiment)
# ----> 4     pred = analyze_sentiment_vader_lexicon(review, threshold=0.4, verbose=True)
#       5     print('-'*60)
#
# <ipython-input-15-2352e6d06117> in analyze_sentiment_vader_lexicon(review, threshold, verbose)
#      22         sentiment_frame = pd.DataFrame([[final_sentiment, final, positive,
#      23                                         negative, neutral]],
# ---> 24                                         columns=pd.MultiIndex(levels=[['SENTIMENT STATS:'],
#      25                                                                       ['Predicted Sentiment', 'Polarity Score',
#      26                                                                        'Positive', 'Negative', 'Neutral']],
#
# TypeError: __new__() got an unexpected keyword argument 'labels'

# %% [markdown]
# ## Predict sentiment for test dataset

# %%
predicted_sentiments = [analyze_sentiment_vader_lexicon(review, threshold=0.4, verbose=False) for review in test_reviews]

# %% [markdown]
# ## Evaluate model performance

# %%
# Performance Metrics on VADER
# Please Note : the module meu is not been provided.
meu.display_model_performance_metrics(true_labels=test_sentiments, predicted_labels=predicted_sentiments, 
                                  classes=['positive', 'negative'])

# THE BELOW O/P SHOULD GIVE YOU A FAIR IDEA ON WHAT :
# methods like 
# display_model_performance_metrics() are doing and printing as o/p.

# As an Intern you are not suppose to produce the exact o/p 
# You may only code the minimum required metrics which helps you to 
# compare the different ML models.
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.7107
# Precision: 0.7236
# Recall: 0.7107
# F1 Score: 0.7064
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#     positive       0.67      0.83      0.74      7510
#     negative       0.78      0.59      0.67      7490
#
#     accuracy                           0.71     15000
#    macro avg       0.72      0.71      0.71     15000
# weighted avg       0.72      0.71      0.71     15000
#
#
# Prediction Confusion Matrix:
# ------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-717f7f2dd5fc> in <module>
#       1 # Performance Metrics on VADER
#       2 # Please Note : the module meu is not been provided.
# ----> 3 meu.display_model_performance_metrics(true_labels=test_sentiments, predicted_labels=predicted_sentiments,
#       4                                   classes=['positive', 'negative'])
#       5
#
# ~/Downloads/Sentiment Analysis Project Specs n Resources/model_evaluation_utils.py in display_model_performance_metrics(true_labels, predicted_labels, classes)
#      83     print('\nPrediction Confusion Matrix:')
#      84     print('-'*30)
# ---> 85     display_confusion_matrix(true_labels=true_labels, predicted_labels=predicted_labels,
#      86                              classes=classes)
#      87
#
# ~/Downloads/Sentiment Analysis Project Specs n Resources/model_evaluation_utils.py in display_confusion_matrix(true_labels, predicted_labels, classes)
#      58                                   labels=classes)
#      59     cm_frame = pd.DataFrame(data=cm,
# ---> 60                             columns=pd.MultiIndex(levels=[['Predicted:'], classes],
#      61                                                   labels=level_labels),
#      62                             index=pd.MultiIndex(levels=[['Actual:'], classes],
#
# TypeError: __new__() got an unexpected keyword argument 'labels'
